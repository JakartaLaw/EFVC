# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from modules.threestagemodel import ThreeStageModel
# %matplotlib inline

# %%
l = [0, 5, 10] #list of periods
d = {'a': [-0.15, -0.15, -0.15], 'p': [-0.15, 0.04, 0.08], 'g': [0.657, 0.4, 0.03]} # dictionary of KPIs
s = 3.314 # sales in period 0

# %%
m = ThreeStageModel(d, l, s)
df = m.run_model(0.1, 20)

# %% [markdown]
# # Plotting

# %%
plt.plot(m.FCF_growth())

# %%
m.enterprise_value(16)
# Out:
# the price is (gordons formula): 43.00440251572331
# the cumulative value of firm is: 34.79
# the sum of these components is:
# 77.7944025157233

# %% [markdown]
# # Latex output of model

# %%
m.latex_output()
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &  year &   sales &     g &     a &     p &    FCF &  NPV FCF &  cum NPV FCF \\
# \midrule
# 0  &     0 &    3.31 &  0.66 & -0.15 & -0.15 &   0.00 &     0.00 &         0.00 \\
# 1  &     1 &    5.49 &  0.66 & -0.15 & -0.15 &  -0.50 &    -0.45 &        -0.45 \\
# 2  &     2 &    9.10 &  0.66 & -0.15 & -0.15 &  -0.82 &    -0.68 &        -1.13 \\
# 3  &     3 &   15.08 &  0.66 & -0.15 & -0.15 &  -1.36 &    -1.03 &        -2.16 \\
# 4  &     4 &   24.98 &  0.66 & -0.15 & -0.15 &  -2.26 &    -1.54 &        -3.70 \\
# 5  &     5 &   34.98 &  0.40 & -0.15 &  0.04 &   2.90 &     1.80 &        -1.90 \\
# 6  &     6 &   48.97 &  0.40 & -0.15 &  0.04 &   4.06 &     2.29 &         0.39 \\
# 7  &     7 &   68.55 &  0.40 & -0.15 &  0.04 &   5.68 &     2.91 &         3.30 \\
# 8  &     8 &   95.97 &  0.40 & -0.15 &  0.04 &   7.95 &     3.71 &         7.01 \\
# 9  &     9 &  134.36 &  0.40 & -0.15 &  0.04 &  11.13 &     4.72 &        11.73 \\
# ...

# %% [markdown]
# ### Question 3

# %%
ai5, ai10, asset_intensity = m.SimulateAssetIntensity()

# %%
gi5, gi10, growth = m.SimulateGrowth()

# %% [markdown]
# # Plotting

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (15, 4))
ax1.plot(asset_intensity, ai5, label='year 5')
ax1.plot(asset_intensity, ai10, label='year 10')
ax1.legend()
ax1.set_xlabel('difference in asset intensity')
ax1.set_ylabel('cumulative NPV FCF')

ax2.plot(growth, gi5, label='year 5')
ax2.legend()
ax2.set_xlabel('difference in growth')
ax2.set_ylabel('cumulative NPV FCF')


ax3.plot(growth, gi10, label='year 10')
ax3.legend()
ax3.set_xlabel('difference in growth')
ax3.set_ylabel('cumulative NPV FCF')
f.savefig('problemset2.png')
